# %% [markdown]
# <a href="https://colab.research.google.com/github/aminfazy/basic_MLDL/blob/main/Nand_gate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## This is a simple example of NAND gate using neural network

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
# Out:
# Using TensorFlow backend.

# %%
# The input and output
# This will be used to train the network

# Input to the gate
x_train = np.array([[0,0],[0,1],[1,0],[1,1]], "uint8") 

# Ouput of the gate, the truth value
y_train = np.array([[1],[1],[1],[0]], "uint8")

# %%
# Create neural networks model
# A sequential model is one where layers are stacked one
# after another and there is not skipping, feedback and
# distributed connection
model = Sequential()

# Add layers to the model
model.add(Dense(output_dim=3, activation='relu', input_dim=2))      # first hidden layer
model.add(Dense(output_dim=3, activation='relu'))                   # second hidden layer
model.add(Dense(output_dim=1, activation='sigmoid'))                # output layer
# Out:
# WARNING:tensorflow:From /home/fazy/anaconda2/envs/retnet/lib/python2.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# /home/fazy/anaconda2/envs/retnet/lib/python2.7/site-packages/ipykernel_launcher.py:8: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=3, activation="relu", input_dim=2)`
#
# /home/fazy/anaconda2/envs/retnet/lib/python2.7/site-packages/ipykernel_launcher.py:9: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=3, activation="relu")`
#   if __name__ == '__main__':
# /home/fazy/anaconda2/envs/retnet/lib/python2.7/site-packages/ipykernel_launcher.py:10: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=1, activation="sigmoid")`
#   # Remove the CWD from sys.path while we load stuff.

# %%
# Compile the neural networks model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Train the neural networks model
model.fit(x_train, y_train, nb_epoch=500)
# Out:
# WARNING:tensorflow:From /home/fazy/anaconda2/envs/retnet/lib/python2.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# /home/fazy/anaconda2/envs/retnet/lib/python2.7/site-packages/ipykernel_launcher.py:4: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   after removing the cwd from sys.path.
# Epoch 1/500
# 4/4 [==============================] - 1s 199ms/step - loss: 0.7639 - acc: 0.2500
# Epoch 2/500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.7630 - acc: 0.5000
# Epoch 3/500
# 4/4 [==============================] - 0s 518us/step - loss: 0.7620 - acc: 0.5000
# Epoch 4/500
# 4/4 [==============================] - 0s 747us/step - loss: 0.7608 - acc: 0.5000
# Epoch 5/500
# 4/4 [==============================] - 0s 702us/step - loss: 0.7597 - acc: 0.5000
# Epoch 6/500
# ...

# %%
# Test the output of the trained neural networks based NAND gate
y_predict = model.predict(x_train)
print(y_predict)
 
# save model as h5 file
model.save("nand.h5")
# Out:
# [[0.6858362]
#  [0.6534095]
#  [0.7045355]
#  [0.3604831]]
